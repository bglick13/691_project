# %%
import os, sys
import numpy as np
import pandas as pd
import pickle
import torch
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
os.chdir('..')
os.getcwd()
# Out:
# 'C:\\Users\\Ben\\Documents\\UMass\\Fall2019\\CS691\\691_project'

# %%
with open('scripts/experiment_6_sl200_with_ratings_mask_pct10_data_pct50/history_movie_pretrain_with_ratings_200_big_data_8.pickle', 'rb') as f:
    exp1 = pickle.load(f)

# %%
fig, ax = plt.subplots(figsize=(17, 8))
ax.plot(exp1['matching_acc'])
ax.plot(exp1['masked_movie_acc'])
ax.plot(exp1['masked_rating_acc'])

# %%
model = torch.load('scripts/experiment_6_sl200_with_ratings_mask_pct10_data_pct50/movie_pretrain_with_ratings_200_big_data_checkpoint_8.torch')

# %%
model.masked_movie_output_bias
# Out:
# Parameter containing:
# tensor([  0.5896,   0.3914,   0.0789,  ..., -11.5679, -11.5284, -11.5122],
#        device='cuda:0', requires_grad=True)
